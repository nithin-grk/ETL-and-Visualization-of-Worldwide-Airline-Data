# %% [markdown]
# <a href="https://colab.research.google.com/github/nithin-grk/ETL-and-Visualization-of-Worldwide-Airline-Data/blob/main/Small_Test_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
print("Hello to you too")
# Out:
# Hello World
